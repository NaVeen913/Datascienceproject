# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Naveen Krishna\\mlops\\Datascience project\\Datascienceproject'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Naveen Krishna\\mlops\\Datascience project'

# %%
import zipfile
import os

zip_path = "artifacts/data_ingestion/data.zip"
extract_to = "artifacts/data_ingestion"

with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(extract_to)

print("After unzip:", os.listdir(extract_to))
# Out:
# After unzip: ['data.zip', 'gettingstarted.ipynb']

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Naveen Krishna\mlops\Datascience project\Datascienceproject\venv\python.exe

# %%
import os

print("CWD:", os.getcwd())
print("Here I see:", os.listdir())
# Out:
# CWD: c:\Users\Naveen Krishna\mlops\Datascience project\Datascienceproject\research
# Here I see: ['1.data_ingestion.ipynb', 'data_validation.ipynb', 'logs', 'research.ipynb']

# %%
import os

os.chdir("..")   # go up from 'research' to 'Datascienceproject'
print("NEW CWD:", os.getcwd())
print("Top level:", os.listdir())
# Out:
# NEW CWD: c:\Users\Naveen Krishna\mlops\Datascience project\Datascienceproject
# Top level: ['.git', '.gitignore', '.gthub', 'app.py', 'artifacts', 'config', 'Dockerfile', 'logs', 'main.py', 'params.yaml', 'README.md', 'requirement.txt', 'research', 'schema.yaml', 'setup.py', 'src', 'template.py', 'templates', 'venv']

# %%
import os

print("artifacts:", os.listdir("artifacts"))
print("data_ingestion:", os.listdir("artifacts/data_ingestion"))
# Out:
# artifacts: ['data_ingestion']
# data_ingestion: ['data.zip', 'gettingstarted.ipynb']

# %%
print(os.listdir("artifacts"))
# Out:
# ['data_ingestion']

# %%
import os

print("CWD:", os.getcwd())
print("artifacts:", os.listdir("artifacts"))
print("data_ingestion:", os.listdir("artifacts/data_ingestion"))
# Out:
# CWD: c:\Users\Naveen Krishna\mlops\Datascience project\Datascienceproject
# artifacts: ['data_ingestion']
# data_ingestion: ['data.zip', 'gettingstarted.ipynb']

# %%
import os
print(os.getcwd())
print(os.listdir("../artifacts"))
# Out:
# c:\Users\Naveen Krishna\mlops\Datascience project\Datascienceproject\research
# ['data_ingestion']

# %%
import os
print("Before:", os.getcwd())

# go from ...\Datascienceproject\research  ->  ...\Datascienceproject
os.chdir("..")

print("After :", os.getcwd())
# Out:
# Before: c:\Users\Naveen Krishna\mlops\Datascience project\Datascienceproject\research
# After : c:\Users\Naveen Krishna\mlops\Datascience project\Datascienceproject

# %%
import os

print(os.getcwd())
print(os.path.exists("../artifacts/data_ingestion/gettingstarted.csv"))
# Out:
# c:\Users\Naveen Krishna\mlops\Datascience project
# False

# %%
import os
os.chdir("Datascienceproject")
print(os.getcwd())
# Out:
# c:\Users\Naveen Krishna\mlops\Datascience project\Datascienceproject

# %%
import os
print(os.path.exists("artifacts/data_ingestion/gettingstarted.csv"))
# Out:
# False

# %%
import os
print(os.listdir("artifacts"))
# Out:
# ['data_ingestion']

# %%
import pandas as pd

df = pd.read_csv("artifacts/data_ingestion/gettingstarted.csv")
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# ...

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
df.shape
# Out:
# (150, 5)

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass
class DataValidationConfig:
    root_dir: Path
    STATUS_FILE: str
    unzip_data_dir: Path
    all_schema: dict

# %%
from src.datascience.constants import *
from src.datascience.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(self,
                 config_filepath=CONFIG_FILE_PATH,
                 params_filepath=PARAMS_FILE_PATH,
                 schema_file_path=SCHEMA_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_file_path)

        create_directories([self.config.artifact_root])

    def get_data_validation_config(self) -> DataValidationConfig:
        config = self.config.data_validation   # 👈 IMPORTANT
        schema = self.schema                   # 👈 to grab COLUMNS

        create_directories([config.root_dir])

        data_validation_config = DataValidationConfig(
            root_dir=Path(config.root_dir),
            STATUS_FILE=config.STATUS_FILE,
            unzip_data_dir=Path(config.unzip_data_dir),
            all_schema=schema.COLUMNS         # 👈 pass schema columns
        )
        return data_validation_config

# %%
import os
from src.datascience import logger

# %%
import pandas as pd

class DataValidation:
    def __init__(self, config: DataValidationConfig):
        self.config = config

    def validate_all_columns(self) -> bool:
        try:
            validation_status = None

            # 1) read csv
            df = pd.read_csv(self.config.unzip_data_dir)

            # 2) columns from file and from schema
            all_cols = list(df.columns)
            all_schema = list(self.config.all_schema.keys())

            # 3) check each column
            for col in all_cols:
                if col not in all_schema:
                    validation_status = False
                    with open(self.config.STATUS_FILE, "w") as f:
                        f.write(f"validation status: {validation_status}")
                    break
            else:
                # runs only if loop DID NOT break => all columns OK
                validation_status = True
                with open(self.config.STATUS_FILE, "w") as f:
                    f.write(f"validation status: {validation_status}")

            return validation_status

        except Exception as e:
            raise e

# %%
config_manager = ConfigurationManager()
data_val_config = config_manager.get_data_validation_config()
validator = DataValidation(data_val_config)

status = validator.validate_all_columns()
print("Final validation status:", status)
# Out:
# [2025-11-29 09:56:48,208: INFO: common: YAML file loaded successfully: config\config.yaml]
# [2025-11-29 09:56:48,210: INFO: common: YAML file loaded successfully: params.yaml]
# [2025-11-29 09:56:48,220: INFO: common: YAML file loaded successfully: schema.yaml]
# [2025-11-29 09:56:48,221: INFO: common: Created directory: artifacts]
# [2025-11-29 09:56:48,223: INFO: common: Created directory: artifacts/data_validation]
# Final validation status: True
